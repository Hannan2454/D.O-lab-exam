# %% [markdown]
# <a href="https://colab.research.google.com/github/Hannan2454/D.O-lab-exam/blob/main/D_O_lab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pd.read_excel('EVENmm.xlsx')
# Out:
#      Booking_ID Customer_ID   Destination             Travel_Dates  \
# 0      BKG01438    CUST5663     BANGALORE  2024-05-27 - 2025-06-02
# 1      BKG02701    CUST4963       Vietnam  2024/05/02 / 2025/06/28
# 2      BKG03648    cust5625         Tokyo  2023-12-02 - 2025-03-09
# 3      BKG02513    CUST4246         Delhi  2023-11-10 - 2024-09-13
# 4      bkg02903    CUST3901       Chennai  2023-11-09 - 2024-08-22
# ...         ...         ...           ...                      ...
# 5245   BKG03093    CUST4090   BRANDYVILLE  2024-01-23 - 2025-04-15
# 5246   BKG03773    CUST0249   SAINT LUCIA  2023-12-11 - 2025-01-11
# 5247   bkg04354    CUST3227         Delhi  2024-06-13 - 2025-04-10
# 5248        NaN         NaN           NaN                      NaN
# 5249   BKG00861    CUST1529  Turkmenistan  2024-05-11 - 2024-11-06
#
#      Booking_Date  Number_of_Travelers Travel_Package Payment_Method  \
# 0      2023-07-26                  3.0        Premium     Debit Card
# ...

# %%
average_cost_by_destination = df.groupby('Destination')['Total_Cost'].mean()
print(average_cost_by_destination)
# Out:
# Destination
# ALBANIA           73664.210000
# ALEJANDROSHIRE    78168.730000
# ARUBA              8573.290000
# Adamsbury         22309.600000
# Adamsfurt         15705.440000
#                       ...
# Zacharyberg       41751.850000
# Zambia            20658.930000
# Zamoramouth       84404.310000
# Zimbabwe          31329.406667
# Zimmermantown     59139.600000
# Name: Total_Cost, Length: 858, dtype: float64

# %%
payment_distribution = df.groupby('Customer_ID')['Payment_Method'].value_counts().unstack(fill_value=0)
print(payment_distribution)
# Out:
# Payment_Method  Bank Transfer  Credit Card  Debit Card  PayPal
# Customer_ID
# CUST0004                    1            0           0       0
# CUST0006                    1            2           1       0
# CUST0016                    0            1           0       0
# CUST0020                    0            0           0       1
# CUST0023                    0            0           0       1
# ...                       ...          ...         ...     ...
# cust9873                    1            0           0       0
# cust9921                    0            1           0       0
# cust9933                    0            0           1       0
# cust9990                    0            0           1       0
# cust9991                    0            1           0       0
#
# [3449 rows x 4 columns]

# %%
unique_destinations = df['Destination'].unique()
num_unique_destinations = len(unique_destinations)
print(f"There are {num_unique_destinations} unique destinations in the dataset.")
# Out:
# There are 859 unique destinations in the dataset.

# %%
df['Travel_Dates'] = pd.to_datetime(df['Travel_Dates'], utc=True)
df['Trip_Duration'] = (df['Travel_Dates'].max() - df['Travel_Dates']).dt.days

# %%
df.head
# Out:
# <bound method NDFrame.head of      Booking_ID Customer_ID   Destination              Travel_Dates  \
# 0      BKG01438    CUST5663     BANGALORE 2024-05-27 22:25:00+00:00
# 1      BKG02701    CUST4963       Vietnam                       NaT
# 2      BKG03648    cust5625         Tokyo 2023-12-03 05:25:00+00:00
# 3      BKG02513    CUST4246         Delhi 2023-11-11 09:24:00+00:00
# 4      bkg02903    CUST3901       Chennai 2023-11-10 18:24:00+00:00
# ...         ...         ...           ...                       ...
# 5245   BKG03093    CUST4090   BRANDYVILLE 2024-01-24 11:25:00+00:00
# 5246   BKG03773    CUST0249   SAINT LUCIA 2023-12-12 07:25:00+00:00
# 5247   bkg04354    CUST3227         Delhi 2024-06-14 06:25:00+00:00
# 5248        NaN         NaN           NaN                       NaT
# 5249   BKG00861    CUST1529  Turkmenistan 2024-05-12 02:24:00+00:00
#
#      Booking_Date  Number_of_Travelers Travel_Package Payment_Method  \
# ...
